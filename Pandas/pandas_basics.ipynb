# %% [markdown]
# # Pandas

# %% [markdown]
# For data manipulation and analysis. Two primary data-structures.
# - Series - One-Dimensional Array like object, can hold any type of data like a column in a table.
# - Dataframe - Two-Dimensional, size-mutable, heterogenous tabular data structure with labeled axes.

# %%
import pandas as pd

# %% [markdown]
# ### 1. Series

# %%
# Basic
data = [1,2,3,4,5]                      # Can use tuples too but NOT SET...

series = pd.Series(data)
print(series)
print(type(series))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# Custom indexing
data = {'a' : 1, 'b': 2, 'c': 3}

series = pd.Series(data)
print(series, '\n')


# OR we can do like this
data = [1,2,3,4,5]
idx = ['a','b','c','d','e']

series = pd.Series(data, index = idx)
print(series, '\n')


# But if I do like this
data = {'a': 1, 'b': 2}
idx = ['d', 'e']
# idx = ['a', 'e']          # a    1.0
                            # e    NaN
                            # dtype: float64

series = pd.Series(data, index = idx)
print(series)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
#
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
#
# d   NaN
# e   NaN
# dtype: float64

# %% [markdown]
# ### 2. Dataframes

# %%
# Basic
data = {'Name': ['Sri', 'Riz', 'Sam', 'Dik'],
        'Age': [21, 21, 22, 19],
        'Marks': [93, 98, 97, 99]
        }

df = pd.DataFrame(data)
print(df)
print(type(df), '\n')

print(df['Age'][1])

df
# Out:
#   Name  Age  Marks
# 0  Sri   21     93
# 1  Riz   21     98
# 2  Sam   22     97
# 3  Dik   19     99
# <class 'pandas.core.frame.DataFrame'>
#
# 21
#   Name  Age  Marks
# 0  Sri   21     93
# 1  Riz   21     98
# 2  Sam   22     97
# 3  Dik   19     99

# %%
# Convert into numpy array
import numpy as np

arr = np.array(df)
arr
# Out:
# array([['Sri', 21, 93],
#        ['Riz', 21, 98],
#        ['Sam', 22, 97],
#        ['D', 19, 99]], dtype=object)

# %%
# Alternate ways of creation

data = [                            # Using list of dicts...
    {'Name': 'sri', 'Age': 21},
    {'Name': 'Riz', "Age": 20},
    {'Name': 'Sam', 'Age': 21},
    {'Name': 'Dik'}
]

idx = ['a','b','c','d']             # Custom Indexing...

df = pd.DataFrame(data, index=idx)
df
# Out:
#   Name   Age
# a  sri  21.0
# b  Riz  20.0
# c  Sam  21.0
# d  Dik   NaN

# %%
# Accessing elements

print(df['Name'])
print(type(df['Name']), '\n')

print(df.loc['a'])                # Accessing by rows...
print(type(df.loc['a']), '\n')

print(df.iloc[0], '\n')           # Accessing by index...

# Using at method...
print(df.at['a', 'Name'],'\n')
print(df.iat[0,1])

# Modifying
df.iat[0,0] = 'Sharukh'
df
# Out:
# a    sri
# b    Riz
# c    Sam
# d    Dik
# Name: Name, dtype: object
# <class 'pandas.core.series.Series'>
#
# Name    sri
# Age      21
# Name: a, dtype: object
# <class 'pandas.core.series.Series'>
#
# Name    sri
# Age      21
# Name: a, dtype: object
#
# sri
#
# 21
#       Name  Age
# a  Sharukh   21
# b      Riz   20
# c      Sam   21
# d      Dik   19

# %% [markdown]
# ### 3. Some Manipulations

# %%
# Adding column...
df['Salary'] = [1000, 2000, 3000, 4000]
df
# Out:
#   Name  Age  Salary
# a  sri   21    1000
# b  Riz   20    2000
# c  Sam   21    3000
# d  Dik   19    4000

# %%
# Removing Column...
df.drop('Salary', axis=1)  # This only do Temporary Change. For permanent - use "df.drop('Salary', axis=1, inplace = True)"
# Out:
#   Name  Age
# a  sri   21
# b  Riz   20
# c  Sam   21
# d  Dik   19

# %%
df.drop('a')
# For default indexing use df.drop(0)
# Out:
#   Name  Age  Salary
# b  Riz   20    2000
# c  Sam   21    3000
# d  Dik   19    4000

# %%
df
# Out:
#   Name  Age  Salary
# a  sri   21    1000
# b  Riz   20    2000
# c  Sam   21    3000
# d  Dik   19    4000

# %%
df.describe()
# Out:
#              Age       Salary
# count   4.000000     4.000000
# mean   20.250000  2500.000000
# std     0.957427  1290.994449
# min    19.000000  1000.000000
# 25%    19.750000  1750.000000
# 50%    20.500000  2500.000000
# 75%    21.000000  3250.000000
# max    21.000000  4000.000000

# %% [markdown]
# ### # Common Errors

# %%
pd.Series({1,2,3,4})                    # SET cannot be used
df.drop("Salary")                       # Default axis is 0 (row) for column axis is 1
