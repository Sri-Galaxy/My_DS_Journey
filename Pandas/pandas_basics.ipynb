# %% [markdown]
# # Pandas

# %% [markdown]
# For data manipulation and analysis. Two primary data-structures.
# - Series - One-Dimensional Array like object, can hold any type of data like a column in a table.
# - Dataframe - Two-Dimensional, size-mutable, heterogenous tabular data structure with labeled axes.

# %%
import pandas as pd

# %% [markdown]
# ### 1. Series

# %%
# Basic
data = [1,2,3,4,5]                      # Can use tuples too but NOT SET...

series = pd.Series(data)
print(series)
print(type(series))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# Custom indexing
data = {'a' : 1, 'b': 2, 'c': 3}

series = pd.Series(data)
print(series, '\n')


# OR we can do like this
data = [1,2,3,4,5]
idx = ['a','b','c','d','e']

series = pd.Series(data, index = idx)
print(series, '\n')


# But if I do like this
data = {'a': 1, 'b': 2}
idx = ['d', 'e']
# idx = ['a', 'e']          # a    1.0
                            # e    NaN
                            # dtype: float64

series = pd.Series(data, index = idx)
print(series)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
#
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
#
# d   NaN
# e   NaN
# dtype: float64

# %% [markdown]
# ### 2. Dataframes

# %%
# Basic
data = {'Name': ['Sri', 'Riz', 'Sam', 'Dik'],
        'Age': [21, 21, 22, 19],
        'Marks': [93, 98, 97, 99]
        }

df = pd.DataFrame(data)
print(df)
print(type(df), '\n')

print(df['Age'][1])

df
# Out:
#   Name  Age  Marks
# 0  Sri   21     93
# 1  Riz   21     98
# 2  Sam   22     97
# 3  Dik   19     99
# <class 'pandas.core.frame.DataFrame'>
#
# 21
#   Name  Age  Marks
# 0  Sri   21     93
# 1  Riz   21     98
# 2  Sam   22     97
# 3  Dik   19     99

# %%
# Convert into numpy array
import numpy as np

arr = np.array(df)
arr
# Out:
# array([['Sri', 21, 93],
#        ['Riz', 21, 98],
#        ['Sam', 22, 97],
#        ['Dik', 19, 99]], dtype=object)

# %%
# Alternate ways of creation

data = [                            # Using list of dicts...
    {'Name': 'sri', 'Age': 21},
    {'Name': 'Riz', "Age": 20},
    {'Name': 'Sam', 'Age': 21},
    {'Name': 'Dik'}
]

idx = ['a','b','c','d']             # Custom Indexing...

df = pd.DataFrame(data, index=idx)
df
# Out:
#   Name   Age
# a  sri  21.0
# b  Riz  20.0
# c  Sam  21.0
# d  Dik   NaN

# %%
# Accessing elements

print(df['Name'])
print(type(df['Name']), '\n')

print(df.loc['a'])                # Accessing by rows...
print(type(df.loc['a']), '\n')

print(df.iloc[0], '\n')           # Accessing by index...

# Using at method...
print(df.at['a', 'Name'],'\n')
print(df.iat[0,1])

# Modifying
df.iat[0,0] = 'Sharukh'
df
# Out:
# a    sri
# b    Riz
# c    Sam
# d    Dik
# Name: Name, dtype: object
# <class 'pandas.core.series.Series'>
#
# Name     sri
# Age     21.0
# Name: a, dtype: object
# <class 'pandas.core.series.Series'>
#
# Name     sri
# Age     21.0
# Name: a, dtype: object
#
# sri
#
# 21.0
#       Name   Age
# a  Sharukh  21.0
# b      Riz  20.0
# c      Sam  21.0
# d      Dik   NaN

# %% [markdown]
# ### 3. Some Manipulations

# %%
# Adding column...
df['Salary'] = [1000, 2000, 3000, 4000]
df
# Out:
#       Name   Age  Salary
# a  Sharukh  21.0    1000
# b      Riz  20.0    2000
# c      Sam  21.0    3000
# d      Dik   NaN    4000

# %%
# Removing Column...
df.drop('Salary', axis=1)  # This only do Temporary Change. For permanent - use "df.drop('Salary', axis=1, inplace = True)"
# Out:
#       Name   Age
# a  Sharukh  21.0
# b      Riz  20.0
# c      Sam  21.0
# d      Dik   NaN

# %%
df.drop('a')
# For default indexing use df.drop(0)
# Out:
#   Name   Age  Salary
# b  Riz  20.0    2000
# c  Sam  21.0    3000
# d  Dik   NaN    4000

# %%
df
# Out:
#       Name   Age  Salary
# a  Sharukh  21.0    1000
# b      Riz  20.0    2000
# c      Sam  21.0    3000
# d      Dik   NaN    4000

# %%
df.describe()
# Out:
#              Age       Salary
# count   3.000000     4.000000
# mean   20.666667  2500.000000
# std     0.577350  1290.994449
# min    20.000000  1000.000000
# 25%    20.500000  1750.000000
# 50%    21.000000  2500.000000
# 75%    21.000000  3250.000000
# max    21.000000  4000.000000

# %% [markdown]
# ### # Common Errors

# %%
pd.Series({1,2,3,4})                    # SET cannot be used
df.drop("Salary")                       # Default axis is 0 (row) for column axis is 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 pd.Series({1,2,3,4})                    # SET cannot be used
#       2 df.drop("Salary")                       # Default axis is 0 (row) for column axis is 1
#
# File d:\DS_Prac\.venv\Lib\site-packages\pandas\core\series.py:584, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     582         data = data.copy()
#     583 else:
# --> 584     data = sanitize_array(data, index, dtype, copy)
#     586     manager = _get_option("mode.data_manager", silent=True)
#     587     if manager == "block":
#
# File d:\DS_Prac\.venv\Lib\site-packages\pandas\core\construction.py:639, in sanitize_array(data, index, dtype, copy, allow_2d)
#     630     return sanitize_array(
#     631         data,
#     632         index=index,
#    (...)    635         allow_2d=allow_2d,
#     636     )
#     638 else:
# --> 639     _sanitize_non_ordered(data)
#     640     # materialize e.g. generators, convert e.g. tuples, abc.ValueView
#     641     data = list(data)
#
# File d:\DS_Prac\.venv\Lib\site-packages\pandas\core\construction.py:690, in _sanitize_non_ordered(data)
#     686 """
#     687 Raise only for unordered sets, e.g., not for dict_keys
#     688 """
#     689 if isinstance(data, (set, frozenset)):
# --> 690     raise TypeError(f"'{type(data).__name__}' type is unordered")
#
# TypeError: 'set' type is unordered
