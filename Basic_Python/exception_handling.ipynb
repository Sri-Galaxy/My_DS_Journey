# %%
class DobError(Exception):
    pass

try:
    n = int(input())

    if (n < 0 or n > 60):
        raise DobError
    else:
        print("Eligible to Vote")
except DobError:
    print("Sorry! Not Eligible...")
# Out:
# Sorry! Not Eligible...
